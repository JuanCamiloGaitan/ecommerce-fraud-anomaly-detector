# %%
# Importar librerías fundamentales para análisis y modelado
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración estética para los gráficos
sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = (10, 6)

print("¡Entorno de trabajo configurado con éxito!")
print("Pandas version:", pd.__version__)
print("NumPy version:", np.__version__)
# Out:
# ¡Entorno de trabajo configurado con éxito!
# Pandas version: 3.0.0
# NumPy version: 2.4.2

# %%
from sklearn.datasets import make_classification

# Generamos un dataset sintético altamente desbalanceado (simulando transacciones de e-commerce)
# Donde solo el 1% de las transacciones son fraude (anomalías reales)
X, y = make_classification(
    n_samples=10000, 
    n_features=5, 
    n_informative=4, 
    n_redundant=1, 
    weights=[0.99, 0.01], 
    random_state=42
)

# Convertimos los datos a un DataFrame de Pandas con nombres de negocio profesionales
df_transacciones = pd.DataFrame(X, columns=[
    'Monto_Transaccion_Normalizado', 
    'Distancia_Ubicacion_Km', 
    'Frecuencia_Compras_Ultima_Hora', 
    'Edad_Cuenta_Dias', 
    'Dispositivo_Sospechoso_Score'
])

df_transacciones['Es_Fraude'] = y

# Visualizamos las primeras 5 filas
print("Primeras transacciones registradas:")
display(df_transacciones.head())

# Verificamos el desbalance de clases (crucial en detección de anomalías)
conteo_fraudes = df_transacciones['Es_Fraude'].value_counts()
print("\nDistribución de clases (0 = Legítima, 1 = Fraude):")
print(conteo_fraudes)
print(f"\nPorcentaje de fraude en el dataset: {(conteo_fraudes[1] / len(df_transacciones)) * 100:.2f}%")
# Out:
# Primeras transacciones registradas:
#    Monto_Transaccion_Normalizado  Distancia_Ubicacion_Km  \
# 0                      -2.299933                3.242833
# 1                      -1.707593                0.122327
# 2                      -0.916655               -0.569816
# 3                       0.805849               -1.691910
# 4                      -2.202056                2.670985
#
#    Frecuencia_Compras_Ultima_Hora  Edad_Cuenta_Dias  \
# 0                        1.879708          0.066115
# 1                       -0.604671         -0.905535
# 2                       -0.719821         -0.782531
# 3                       -2.878510         -0.472700
# 4                       -2.196414          0.248894
#
#    Dispositivo_Sospechoso_Score  Es_Fraude
# 0                      1.102833          0
# 1                     -0.692637          0
# 2                     -0.772442          0
# 3                     -0.355966          0
# 4                      0.691424          0
# Distribución de clases (0 = Legítima, 1 = Fraude):
# Es_Fraude
# 0    9844
# 1     156
# Name: count, dtype: int64
#
# Porcentaje de fraude en el dataset: 1.56%

# %%
from sklearn.ensemble import IsolationForest
from sklearn.metrics import classification_report, confusion_matrix

# 1. Configuramos el modelo de Detección de Anomalías (Isolation Forest)
# contamination=0.0156 porque sabemos que aproximadamente el 1.56% de nuestros datos son anomalías (fraude)
modelo_anomalias = IsolationForest(
    contamination=0.0156, 
    random_state=42
)

# 2. Entrenamos el modelo con nuestras variables de transacciones (excluyendo la columna de etiqueta real)
X_features = df_transacciones.drop(columns=['Es_Fraude'])
modelo_anomalias.fit(X_features)

# 3. Predicciones del modelo
# Isolation Forest predice 1 para datos normales y -1 para anomalías. 
# Lo transformamos a 0 (legítima) y 1 (fraude) para compararlo con nuestra etiqueta real.
predicciones_raw = modelo_anomalias.predict(X_features)
df_transacciones['Prediccion_Anomalia'] = [1 if p == -1 else 0 for p in predicciones_raw]

# 4. Evaluamos los resultados comparando con el fraude real
print("--- Matriz de Confusión ---")
print(confusion_matrix(df_transacciones['Es_Fraude'], df_transacciones['Prediccion_Anomalia']))

print("\n--- Reporte de Clasificación ---")
print(classification_report(df_transacciones['Es_Fraude'], df_transacciones['Prediccion_Anomalia']))
# Out:
# --- Matriz de Confusión ---
# [[9699  145]
#  [ 145   11]]
#
# --- Reporte de Clasificación ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      9844
#            1       0.07      0.07      0.07       156
#
#     accuracy                           0.97     10000
#    macro avg       0.53      0.53      0.53     10000
# weighted avg       0.97      0.97      0.97     10000

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# 1. Dividimos nuestros datos en entrenamiento (80%) y prueba (20%)
X_train, X_test, y_train, y_test = train_test_split(
    X_features, 
    df_transacciones['Es_Fraude'], 
    test_size=0.2, 
    random_state=42, 
    stratify=df_transacciones['Es_Fraude'] # Mantiene la misma proporción de fraude en ambos grupos
)

# 2. Entrenamos un modelo supervisado (Random Forest)
# Usamos class_weight='balanced' para que el modelo le preste atención a la clase minoritaria (fraude)
modelo_supervisado = RandomForestClassifier(
    n_estimators=100, 
    class_weight='balanced', 
    random_state=42
)

modelo_supervisado.fit(X_train, y_train)

# 3. Evaluamos en el conjunto de prueba que el modelo NUNCA ha visto
y_pred = modelo_supervisado.predict(X_test)

print("--- Matriz de Confusión (Modelo Supervisado) ---")
print(confusion_matrix(y_test, y_pred))

print("\n--- Reporte de Clasificación (Modelo Supervisado) ---")
print(classification_report(y_test, y_pred))
# Out:
# --- Matriz de Confusión (Modelo Supervisado) ---
# [[1969    0]
#  [  21   10]]
#
# --- Reporte de Clasificación (Modelo Supervisado) ---
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1969
#            1       1.00      0.32      0.49        31
#
#     accuracy                           0.99      2000
#    macro avg       0.99      0.66      0.74      2000
# weighted avg       0.99      0.99      0.99      2000

# %%
from sklearn.metrics import precision_recall_curve, auc
import matplotlib.pyplot as plt
import numpy as np

# 1. Obtenemos las probabilidades predichas para la clase positiva (fraude = 1) en el conjunto de prueba
# [:, 1] nos da la probabilidad exacta de que sea fraude según Random Forest
y_probs = modelo_supervisado.predict_proba(X_test)[:, 1]

# 2. EXPERIMENTO DE UMBRAL (Threshold Tuning)
# Por defecto es 0.5. Vamos a bajarlo a 0.2 para ser más estrictos y atrapar más fraudes.
nuevo_umbral = 0.2
y_pred_nuevo_umbral = (y_probs >= nuevo_umbral).astype(int)

print(f"--- Matriz de Confusión con Umbral Ajustado ({nuevo_umbral}) ---")
print(confusion_matrix(y_test, y_pred_nuevo_umbral))
print(f"\n--- Reporte de Clasificación (Umbral = {nuevo_umbral}) ---")
print(classification_report(y_test, y_pred_nuevo_umbral))

# 3. GRAFICO DE CURVA PRECISION-RECALL (PR-AUC)
precision, recall, thresholds = precision_recall_curve(y_test, y_probs)
pr_auc = auc(recall, precision)

plt.figure(figsize=(8, 5))
plt.plot(recall, precision, color='purple', lw=2, label=f'Random Forest (PR-AUC = {pr_auc:.2f})')
plt.xlabel('Recall (Sensibilidad - Qué tantos fraudes atrapamos)', fontsize=11)
plt.ylabel('Precision (Precisión - Qué tan seguros estamos del fraude)', fontsize=11)
plt.title('Curva Precision-Recall: Detección de Fraude en E-commerce', fontsize=13, fontweight='bold')
plt.legend(loc="lower left")
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

print(f"Área bajo la curva Precision-Recall (PR-AUC): {pr_auc:.4f}")
# Out:
# --- Matriz de Confusión con Umbral Ajustado (0.2) ---
# [[1964    5]
#  [  14   17]]
#
# --- Reporte de Clasificación (Umbral = 0.2) ---
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      1969
#            1       0.77      0.55      0.64        31
#
#     accuracy                           0.99      2000
#    macro avg       0.88      0.77      0.82      2000
# weighted avg       0.99      0.99      0.99      2000
# Área bajo la curva Precision-Recall (PR-AUC): 0.5904

# %%
# 1. Importamos librerías necesarias
import pandas as pd
import numpy as np
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_curve, auc
import matplotlib.pyplot as plt
from xgboost import XGBClassifier

# 2. Generamos el mismo dataset base para mantener consistencia
X, y = make_classification(
    n_samples=10000, 
    n_features=5, 
    n_informative=4, 
    n_redundant=1, 
    weights=[0.99, 0.01], 
    random_state=42
)

X_features = pd.DataFrame(X, columns=[
    'Monto_Transaccion_Normalizado', 
    'Distancia_Ubicacion_Km', 
    'Frecuencia_Compras_Ultima_Hora', 
    'Edad_Cuenta_Dias', 
    'Dispositivo_Sospechoso_Score'
])

# 3. Dividimos en entrenamiento y prueba (80% / 20%)
X_train, X_test, y_train, y_test = train_test_split(
    X_features, 
    y, 
    test_size=0.2, 
    random_state=42, 
    stratify=y
)

# 4. Calculamos scale_pos_weight para manejar el desbalance en XGBoost
# Es la proporción entre transacciones normales y fraudulentas en el conjunto de entrenamiento
conteo_negativas = (y_train == 0).sum()
conteo_positivas = (y_train == 1).sum()
scale_pos_weight_val = conteo_negativas / conteo_positivas

print(f"Factor scale_pos_weight calculado: {scale_pos_weight_val:.2f}")

# 5. Entrenamos el modelo XGBoost
modelo_xgboost = XGBClassifier(
    n_estimators=100,
    learning_rate=0.1,
    max_depth=4,
    scale_pos_weight=scale_pos_weight_val,
    random_state=42
)

modelo_xgboost.fit(X_train, y_train)

# 6. Evaluamos con un umbral optimizado (por ejemplo, 0.3)
y_probs_xgb = modelo_xgboost.predict_proba(X_test)[:, 1]
umbral_xgb = 0.3
y_pred_xgb = (y_probs_xgb >= umbral_xgb).astype(int)

print(f"\n--- Matriz de Confusión (XGBoost con umbral {umbral_xgb}) ---")
print(confusion_matrix(y_test, y_pred_xgb))
print("\n--- Reporte de Clasificación (XGBoost) ---")
print(classification_report(y_test, y_pred_xgb))

# 7. Calculamos el nuevo PR-AUC
precision, recall, _ = precision_recall_curve(y_test, y_probs_xgb)
pr_auc_xgb = auc(recall, precision)
print(f"\nNuevo Área bajo la curva Precision-Recall (PR-AUC con XGBoost): {pr_auc_xgb:.4f}")
# Out:
# Factor scale_pos_weight calculado: 63.00
#
# --- Matriz de Confusión (XGBoost con umbral 0.3) ---
# [[1669  300]
#  [  10   21]]
#
# --- Reporte de Clasificación (XGBoost) ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.85      0.92      1969
#            1       0.07      0.68      0.12        31
#
#     accuracy                           0.84      2000
#    macro avg       0.53      0.76      0.52      2000
# weighted avg       0.98      0.84      0.90      2000
#
#
# Nuevo Área bajo la curva Precision-Recall (PR-AUC con XGBoost): 0.4743
